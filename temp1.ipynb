# %%
from sparse_kernel import distortions, d1_, d2_
import matplotlib.pyplot as plt


plt.plot(range(1,21), distortions, marker = 'o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show()
# Out:
# processing time 0.1421504020690918 with 1 clusters, and inertia_ = 116081700.41967991
# processing time 0.014256000518798828 with 2 clusters, and inertia_ = 40557965.693056196
# processing time 0.002905607223510742 with 3 clusters, and inertia_ = 20309657.166336205
# processing time 0.0023851394653320312 with 4 clusters, and inertia_ = 10019718.248271981
# processing time 0.002523660659790039 with 5 clusters, and inertia_ = 7062307.767983524
# processing time 0.0055294036865234375 with 6 clusters, and inertia_ = 4644576.2042551795
# processing time 0.002899646759033203 with 7 clusters, and inertia_ = 3524948.6469804654
# processing time 0.0031578540802001953 with 8 clusters, and inertia_ = 2693144.706853855
# processing time 0.008971452713012695 with 9 clusters, and inertia_ = 2517588.347668272
# processing time 0.0040776729583740234 with 10 clusters, and inertia_ = 1838463.080918799
# processing time 0.004119873046875 with 11 clusters, and inertia_ = 1569871.9016798171
# processing time 0.00442051887512207 with 12 clusters, and inertia_ = 1346332.2823264776
# processing time 0.004625797271728516 with 13 clusters, and inertia_ = 1255290.9499001403
# processing time 0.004814624786376953 with 14 clusters, and inertia_ = 1050514.2117913559
# processing time 0.00508880615234375 with 15 clusters, and inertia_ = 964987.7173122321
# processing time 0.005191326141357422 with 16 clusters, and inertia_ = 845253.2255406928
# processing time 0.005077362060546875 with 17 clusters, and inertia_ = 796385.8042478096
# processing time 0.005171775817871094 with 18 clusters, and inertia_ = 753504.3268907701
# processing time 0.02258896827697754 with 19 clusters, and inertia_ = 702322.7818171218
# processing time 0.0056400299072265625 with 20 clusters, and inertia_ = 649164.678477395
# [[ 197.99418605  362.25290698]
#  [ 186.24855491  928.87283237]
#  [ 188.51298701  679.995671  ]
#  [ 227.06640625  163.7265625 ]
#  [ 268.98648649 1151.41891892]
#  [ 188.44444444  495.06613757]]

# %%
plt.plot(range(1,20), d1_, marker = 'o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show()

# %%
plt.plot(range(1,19), d2_, marker = 'o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show()

# %%
import numpy as np
np_d2 = np.array(d2_)
print(np.argmin(d2_)+1)
# Out:
# 7
